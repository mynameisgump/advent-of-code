# %%
# Parse and set up input
filename="input-ex.txt"
with open(filename) as f:
    paths = [line.split(" -> ") for line in [line.rstrip().split("\n") for line in f.read().split("\n\n")][0]]#[line.rstrip().split("\n") for line in f.read().split("\n\n")]
for i in range(len(paths)):
    path = paths[i]
    for j in range(len(path)):
        path[j] = list(map(int, path[j].split(",")))
print(paths)
# Out:
# [[[498, 4], [498, 6], [496, 6]], [[503, 4], [502, 4], [502, 9], [494, 9]]]

# %%
from operator import sub

# Creates Rock coordinates
rockMap = []
for path in paths:
    #print("")
    for i in range(len(path)-1):
        coor_1 = path[i]
        coor_2 = path[i+1]  
        diffs = list(map(sub, coor_1, coor_2))
        #print(coor_1,coor_2,diffs)
        # X Case
        if coor_1[0] != coor_2[0]:
            min_x,max_x = min([coor_1[0],coor_2[0]]),max([coor_1[0],coor_2[0]]) 
            # print(min_y,max_y)
            x_ranges = range(min_x,max_x+1)
            for x in x_ranges:
                rockMap.append([x,coor_1[1]])

        # Y Case
        if coor_1[1] != coor_2[1]:
            min_y,max_y = min([coor_1[1],coor_2[1]]),max([coor_1[1],coor_2[1]]) 
            # print(min_y,max_y)
            y_ranges = range(min_y,max_y+1)
            for y in y_ranges:
                rockMap.append([coor_1[0],y])

def printSandMap(sandMap):
    keys = sandMap.keys()
    min_x = min(keys, key=lambda tup: tup[0])[0]
    max_x = max(keys, key=lambda tup: tup[0])[0]
    min_y = min(keys, key=lambda tup: tup[1])[1]
    max_y = max(keys, key=lambda tup: tup[1])[1]

    sand_spout = [500,0]
    # print("Printing Map: ")
    # print(min_x,max_x,min_y,max_y)

    # Buffers for better visuals larger maps
    buff = 4

    for y in range(min_y-buff,max_y+buff):
        row_string = ""
        for x in range(min_x-buff,max_x+buff):
            if (x,y) in sandMap:
                row_string += sandMap[(x,y)]
            else:
                row_string += "."
        print(row_string)

def getColumn(sandMap,x_index,y_index):
    return dict(filter(lambda elem: elem[0][0] == x_index and elem[0][1] >= y_index and elem[1] != "+", sandMap.items()))

def simulateSand(sandMap,steps,start):
    #printSandMap(sandMap)
    #print()
    for i in range(steps):
        #print("Step: ",i)
        column = getColumn(sandMap,start[0],start[1])
        #print("Column: ",column)
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        #print("Closest: ",closest)
        current_loc = (closest[0],closest[1]-1)
        #print("Current Loc: ",current_loc)
        placingSand = True
        while placingSand:
            
            left = (current_loc[0]-1,current_loc[1]+1)
            #print("Left: ", left)
            right = (current_loc[0]+1,current_loc[1]+1)
            #print("Right: ",right)
            if left in sandMap and right in sandMap:
                sandMap[current_loc] = "o"
                placingSand = False
            elif left not in sandMap:
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                column = getColumn(sandMap,right[0],right[1])
            
            if len(column) == 0:
                placingSand = False
                print("Infinite Column")
                break 
            
            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)

    printSandMap(sandMap)

            #placingSand = False
            #     sandMap[left] = "o"
            #     placing_sand = False
            # elif right not in sandMap:
            #     sandMap[right] = "o"
            #     placing_sand = False

        #



        # placing_sand = True
        # column = getColumn(sandMap,start[0],start[1])

        # keys = list(column.keys())
        # keys.sort(key=lambda coord: coord[1],reverse=False)

        # closest = keys[0]
        # if sandMap[closest] == "#":
        #     lowest_y = min(list(map(lambda tup: tup[1],column.keys())))
        #     sandMap[(start[0],lowest_y-1)] = "o"
        #     placing_sand = False
        # elif sandMap[closest] == "o":
        #     placing_sand = True
        #     while placing_sand:
        #         if ()
        #         left = (closest[0]-1,closest[1])
        #         right = (closest[0]+1,closest[1])
        #         cur_coordinate = (closest[0]-1,closest[1])

        #         if cur_coordinate not in sandMap:
        #             sandMap[cur_coordinate] = "o"
        #             placing_sand = False
        #         else:
        #             cur_coordinate = (closest[0]+1,closest[1])
        #             if cur_coordinate not in sandMap:
        #                 sandMap[cur_coordinate] = "o" 
        #                 placing_sand = False
        #         print("Closest: ",closest)
        #         new_column = getColumn(sandMap,closest[0]-1,closest[1]-1)
        #         print("New Column: ",new_column)
            
            
        #printSandMap(sandMap)

            #sorted_keys = sorted(keys, key=lambda coord: coord[1], reverse=True)

        

sandMap = {(500,0): "+"}
for rock in rockMap:
    sandMap[tuple(rock)] = "#"

print("Initial:")
#printSandMap(sandMap)
print()
simulateSand(sandMap,25,(500,0))
#printSandMap(sandMap)
                
        # if diffs[0] < 0:
        #     x_range = list(range(-1,diffs[0]-1,-1))
        # else:
        #     x_range = list(range(1,diffs[0]+1))
        # if diffs[1] < 0:
        #     y_range = list(range(-1,diffs[1]-1,-1))
        # else:
        #     y_range = [range(1,diffs[1]+1)]
        # print(coor_1,coor_2,diffs)   
        # print(coord_ranges)
        # print(x_range,y_range)
# Out:
# Initial:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 152
#     150 #printSandMap(sandMap)
#     151 print()
# --> 152 simulateSand(sandMap,25,(500,0))
#     153 #printSandMap(sandMap)
#     154
#     155         # if diffs[0] < 0:
#    (...)
#     164         # print(coord_ranges)
#     165         # print(x_range,y_range)
#
# Cell In[17], line 84, in simulateSand(sandMap, steps, start)
#      82     keys = list(column.keys())
#      83     keys.sort(key=lambda coord: coord[1],reverse=False)
# ---> 84     closest = keys[0]
#      85     current_loc = (closest[0],closest[1]-1)
#      87 elif right not in sandMap:
#
# IndexError: list index out of range

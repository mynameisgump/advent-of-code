# %%
if __name__ == "__main__":
    filename="input-ex.txt"
    with open(filename) as f:
        commands = [line.rstrip().split(" ") for line in f.readlines()]
print(commands)
# Out:
# [['addx', '15'], ['addx', '-11'], ['addx', '6'], ['addx', '-3'], ['addx', '5'], ['addx', '-1'], ['addx', '-8'], ['addx', '13'], ['addx', '4'], ['noop'], ['addx', '-1'], ['addx', '5'], ['addx', '-1'], ['addx', '5'], ['addx', '-1'], ['addx', '5'], ['addx', '-1'], ['addx', '5'], ['addx', '-1'], ['addx', '-35'], ['addx', '1'], ['addx', '24'], ['addx', '-19'], ['addx', '1'], ['addx', '16'], ['addx', '-11'], ['noop'], ['noop'], ['addx', '21'], ['addx', '-15'], ['noop'], ['noop'], ['addx', '-3'], ['addx', '9'], ['addx', '1'], ['addx', '-3'], ['addx', '8'], ['addx', '1'], ['addx', '5'], ['noop'], ['noop'], ['noop'], ['noop'], ['noop'], ['addx', '-36'], ['noop'], ['addx', '1'], ['addx', '7'], ['noop'], ['noop'], ['noop'], ['addx', '2'], ['addx', '6'], ['noop'], ['noop'], ['noop'], ['noop'], ['noop'], ['addx', '1'], ['noop'], ['noop'], ['addx', '7'], ['addx', '1'], ['noop'], ['addx', '-13'], ['addx', '13'], ['addx', '7'], ['noop'], ['addx', '1'], ['addx', '-33'], ['noop'], ['noop'], ['noop'], ['addx', '2'], ['noop'], ['noop'], ['noop'], ['addx', '8'], ['noop'], ['addx', '-1'], ['addx', '2'], ['addx', '1'], ['noop'], ['addx', '17'], ['addx', '-9'], ['addx', '1'], ['addx', '1'], ['addx', '-3'], ['addx', '11'], ['noop'], ['noop'], ['addx', '1'], ['noop'], ['addx', '1'], ['noop'], ['noop'], ['addx', '-13'], ['addx', '-19'], ['addx', '1'], ['addx', '3'], ['addx', '26'], ['addx', '-30'], ['addx', '12'], ['addx', '-1'], ['addx', '3'], ['addx', '1'], ['noop'], ['noop'], ['noop'], ['addx', '-9'], ['addx', '18'], ['addx', '1'], ['addx', '2'], ['noop'], ['noop'], ['addx', '9'], ['noop'], ['noop'], ['noop'], ['addx', '-1'], ['addx', '2'], ['addx', '-37'], ['addx', '1'], ['addx', '3'], ['noop'], ['addx', '15'], ['addx', '-21'], ['addx', '22'], ['addx', '-6'], ['addx', '1'], ['noop'], ['addx', '2'], ['addx', '1'], ['noop'], ['addx', '-10'], ['noop'], ['noop'], ['addx', '20'], ['addx', '1'], ['addx', '2'], ['addx', '2'], ['addx', '-6'], ['addx', '-11'], ['noop'], ['noop'], ['noop']]

# %%
X=1
index = 0
cycle_timer = 0
final_sum = []
for cycle in range(250):
    if cycle in [19,59,99,139,179,219]:
        print(X*(cycle+1))
        final_sum.append(X*(cycle+1))

    if index > len(commands)-1:
        index = 0
    instruction = commands[index]

    if instruction[0] == "noop":
        index +=1
    elif instruction[0] == "addx":
        if cycle_timer == 0:
            cycle_timer += 1
        elif cycle_timer == 1:
            cycle_timer = 0
            index += 1
            X += int(instruction[1])
            

print()
print(final_sum)
print(sum(final_sum))
# Out:
# 420
# 1140
# 1800
# 2940
# 2880
# 3960
#
# [420, 1140, 1800, 2940, 2880, 3960]
# 13140

# %%
import math
X=1
index = 0
cycle_timer = 0
final_sum = []
sprite_row = list(range(40))
cycle_index = 0
for i in range(len(sprite_row)):
    sprite_row[i] = "."
sprite_row[0] = "#"
sprite_row[1] = "#"
sprite_row[2] = "#"

def clear_sprite(sprite):
    for i in range(len(sprite)):
        sprite[i] = "."

def set_sprite(sprite,index):
    clear_sprite(sprite)
    sprite[index-1] = "#"
    sprite[index] = "#"
    sprite[index+1] = "#"


tv = [list(range(40)),list(range(40)),list(range(40)),list(range(40)),list(range(40)),list(range(40))]
for i in range(len(tv)):
    for j in range(len(tv[i])):
        tv[i][j] = "."

print(tv)
for cycle in range(250):
    cycle_index_row = math.ceil(cycle/40)
    if cycle_index_row > 1:
        cycle_index_column = cycle-(40*cycle_index_row)
    else:
        cycle_index_column = cycle

    print(cycle_index_column)
    tv[cycle_index_row][cycle_index_column] = "#"
    print("Wat?")
    print("".join(tv[cycle_index_row]))

    print([i for i,val in enumerate(sprite_row) if val=="#"])
    print("".join(sprite_row))
    if cycle in [19,59,99,139,179,219]:
        print(X*(cycle+1))
        final_sum.append(X*(cycle+1))

    if index > len(commands)-1:
        index = 0
    instruction = commands[index]

    if instruction[0] == "noop":
        index +=1
    elif instruction[0] == "addx":
        if cycle_timer == 0:
            cycle_timer += 1
        elif cycle_timer == 1:
            cycle_timer = 0
            index += 1
            X += int(instruction[1])
    
    set_sprite(sprite_row,X)

print()
print(final_sum)
print(sum(final_sum))
# Out:
# [['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.'], ['.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.', '.']]
# 0
# Wat?
# #.......................................
# [0, 1, 2]
# ###.....................................
# 1
# Wat?
# .#......................................
# [0, 1, 2]
# ###.....................................
# 2
# Wat?
# .##.....................................
# [15, 16, 17]
# ...............###......................
# 3
# Wat?
# .###....................................
# [15, 16, 17]
# ...............###......................
# 4
# Wat?
# .####...................................
# [4, 5, 6]
# ....###.................................
# 5
# Wat?
# .#####..................................
# [4, 5, 6]
# ....###.................................
# 6
# Wat?
# .######.................................
# [10, 11, 12]
# ..........###...........................
# 7
# Wat?
# .#######................................
# [10, 11, 12]
# ..........###...........................
# 8
# Wat?
# .########...............................
# [7, 8, 9]
# .......###..............................
# 9
# Wat?
# .#########..............................
# [7, 8, 9]
# .......###..............................
# 10
# Wat?
# .##########.............................
# [12, 13, 14]
# ............###.........................
# 11
# Wat?
# .###########............................
# [12, 13, 14]
# ............###.........................
# 12
# Wat?
# .############...........................
# [11, 12, 13]
# ...........###..........................
# 13
# Wat?
# .#############..........................
# [11, 12, 13]
# ...........###..........................
# 14
# Wat?
# .##############.........................
# [3, 4, 5]
# ...###..................................
# 15
# Wat?
# .###############........................
# [3, 4, 5]
# ...###..................................
# 16
# Wat?
# .################.......................
# [16, 17, 18]
# ................###.....................
# 17
# Wat?
# .#################......................
# [16, 17, 18]
# ................###.....................
# 18
# Wat?
# .##################.....................
# [20, 21, 22]
# ....................###.................
# 19
# Wat?
# .###################....................
# [20, 21, 22]
# ....................###.................
# 420
# 20
# Wat?
# .####################...................
# [20, 21, 22]
# ....................###.................
# 21
# Wat?
# .#####################..................
# [19, 20, 21]
# ...................###..................
# 22
# Wat?
# .######################.................
# [19, 20, 21]
# ...................###..................
# 23
# Wat?
# .#######################................
# [24, 25, 26]
# ........................###.............
# 24
# Wat?
# .########################...............
# [24, 25, 26]
# ........................###.............
# 25
# Wat?
# .#########################..............
# [23, 24, 25]
# .......................###..............
# 26
# Wat?
# .##########################.............
# [23, 24, 25]
# .......................###..............
# 27
# Wat?
# .###########################............
# [28, 29, 30]
# ............................###.........
# 28
# Wat?
# .############################...........
# [28, 29, 30]
# ............................###.........
# 29
# Wat?
# .#############################..........
# [27, 28, 29]
# ...........................###..........
# 30
# Wat?
# .##############################.........
# [27, 28, 29]
# ...........................###..........
# 31
# Wat?
# .###############################........
# [32, 33, 34]
# ................................###.....
# 32
# Wat?
# .################################.......
# [32, 33, 34]
# ................................###.....
# 33
# Wat?
# .#################################......
# [31, 32, 33]
# ...............................###......
# 34
# Wat?
# .##################################.....
# [31, 32, 33]
# ...............................###......
# 35
# Wat?
# .###################################....
# [36, 37, 38]
# ....................................###.
# 36
# Wat?
# .####################################...
# [36, 37, 38]
# ....................................###.
# 37
# Wat?
# .#####################################..
# [35, 36, 37]
# ...................................###..
# 38
# Wat?
# .######################################.
# [35, 36, 37]
# ...................................###..
# 39
# Wat?
# .#######################################
# [0, 1, 2]
# ###.....................................
# 40
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[107], line 39
#      36     cycle_index_column = cycle
#      38 print(cycle_index_column)
# ---> 39 tv[cycle_index_row][cycle_index_column] = "#"
#      40 print("Wat?")
#      41 print("".join(tv[cycle_index_row]))
#
# IndexError: list assignment index out of range

# %%
# Parse and set up input
filename="input-ex.txt"
with open(filename) as f:
    paths = [line.split(" -> ") for line in [line.rstrip().split("\n") for line in f.read().split("\n\n")][0]]#[line.rstrip().split("\n") for line in f.read().split("\n\n")]
for i in range(len(paths)):
    path = paths[i]
    for j in range(len(path)):
        path[j] = list(map(int, path[j].split(",")))
print(paths)
# Out:
# [[[498, 4], [498, 6], [496, 6]], [[503, 4], [502, 4], [502, 9], [494, 9]]]

# %%
from operator import sub

# Creates Rock coordinates
rockMap = []
for path in paths:
    #print("")
    for i in range(len(path)-1):
        coor_1 = path[i]
        coor_2 = path[i+1]  
        diffs = list(map(sub, coor_1, coor_2))
        #print(coor_1,coor_2,diffs)
        # X Case
        if coor_1[0] != coor_2[0]:
            min_x,max_x = min([coor_1[0],coor_2[0]]),max([coor_1[0],coor_2[0]]) 
            # print(min_y,max_y)
            x_ranges = range(min_x,max_x+1)
            for x in x_ranges:
                rockMap.append([x,coor_1[1]])

        # Y Case
        if coor_1[1] != coor_2[1]:
            min_y,max_y = min([coor_1[1],coor_2[1]]),max([coor_1[1],coor_2[1]]) 
            # print(min_y,max_y)
            y_ranges = range(min_y,max_y+1)
            for y in y_ranges:
                rockMap.append([coor_1[0],y])

def printSandMap(sandMap):
    keys = sandMap.keys()
    min_x = min(keys, key=lambda tup: tup[0])[0]
    max_x = max(keys, key=lambda tup: tup[0])[0]
    min_y = min(keys, key=lambda tup: tup[1])[1]
    max_y = max(keys, key=lambda tup: tup[1])[1]

    sand_spout = [500,0]
    # print("Printing Map: ")
    # print(min_x,max_x,min_y,max_y)

    # Buffers for better visuals larger maps
    buff = 4

    for y in range(min_y-buff,max_y+buff):
        row_string = ""
        for x in range(min_x-buff,max_x+buff):
            if (x,y) in sandMap:
                row_string += sandMap[(x,y)]
            else:
                row_string += "."
        print(row_string)

def getColumn(sandMap,x_index,y_index):
    return dict(filter(lambda elem: elem[0][0] == x_index and elem[0][1] >= y_index and elem[1] != "+", sandMap.items()))

def simulateSand(sandMap,steps,start):

    for i in range(steps):
        column = getColumn(sandMap,start[0],start[1])
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        current_loc = (closest[0],closest[1]-1)
        placingSand = True
        while placingSand:
            
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)
            if left in sandMap and right in sandMap:
                sandMap[current_loc] = "o"
                placingSand = False
            elif left not in sandMap:
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                column = getColumn(sandMap,right[0],right[1])
            
            if len(column) == 0:
                placingSand = False
                print("Infinite Column")
                break 

            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)

    printSandMap(sandMap)


def findMax(sandMap,start):
    infiniteFound = False
    current_step = 0
    while infiniteFound == False:
        column = getColumn(sandMap,start[0],start[1])
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        current_loc = (closest[0],closest[1]-1)
        placingSand = True
        while placingSand:
            
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)
            if left in sandMap and right in sandMap:
                sandMap[current_loc] = "o"
                placingSand = False
            elif left not in sandMap:
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                column = getColumn(sandMap,right[0],right[1])
            
            if len(column) == 0:
                placingSand = False
                infiniteFound = True
                print("Infinite Column")
                print(current_step)
                break 

            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)
        current_step += 1
    #printSandMap(sandMap)
        

sandMap = {(500,0): "+"}
for rock in rockMap:
    sandMap[tuple(rock)] = "#"

print("Initial:")
print()
#simulateSand(sandMap,25,(500,0))
findMax(sandMap,(500,0))
# Out:
# Initial:
#
# Infinite Column
# 832

# %%
from operator import sub

# Creates Rock coordinates
rockMap = []
for path in paths:
    #print("")
    for i in range(len(path)-1):
        coor_1 = path[i]
        coor_2 = path[i+1]  
        diffs = list(map(sub, coor_1, coor_2))
        #print(coor_1,coor_2,diffs)
        # X Case
        if coor_1[0] != coor_2[0]:
            min_x,max_x = min([coor_1[0],coor_2[0]]),max([coor_1[0],coor_2[0]]) 
            # print(min_y,max_y)
            x_ranges = range(min_x,max_x+1)
            for x in x_ranges:
                rockMap.append([x,coor_1[1]])

        # Y Case
        if coor_1[1] != coor_2[1]:
            min_y,max_y = min([coor_1[1],coor_2[1]]),max([coor_1[1],coor_2[1]]) 
            # print(min_y,max_y)
            y_ranges = range(min_y,max_y+1)
            for y in y_ranges:
                rockMap.append([coor_1[0],y])

floor = max(rockMap, key=lambda tup: tup[1])[1]+2
print("Floor: ", floor)

def printSandMap(sandMap):
    floor = 11
    keys = sandMap.keys()
    min_x = min(keys, key=lambda tup: tup[0])[0]
    max_x = max(keys, key=lambda tup: tup[0])[0]
    min_y = min(keys, key=lambda tup: tup[1])[1]
    max_y = max(keys, key=lambda tup: tup[1])[1]

    sand_spout = [500,0]
    # print("Printing Map: ")
    # print(min_x,max_x,min_y,max_y)

    # Buffers for better visuals larger maps
    buff = 4

    for y in range(min_y-buff,max_y+buff):
        row_string = ""
        for x in range(min_x-buff,max_x+buff):
            if (x,y) in sandMap:
                row_string += sandMap[(x,y)]
            else:
                row_string += "."
        print(row_string)

def getColumn(sandMap,x_index,y_index):
    return dict(filter(lambda elem: elem[0][0] == x_index and elem[0][1] >= y_index and elem[1] != "+", sandMap.items()))

def simulateSand(sandMap,steps,start):

    for i in range(steps):
        column = getColumn(sandMap,start[0],start[1])
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        current_loc = (closest[0],closest[1]-1)
        placingSand = True
        while placingSand:
            
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)
            if left in sandMap and right in sandMap:
                sandMap[current_loc] = "o"
                placingSand = False
            elif left not in sandMap:
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                column = getColumn(sandMap,right[0],right[1])
            
            if len(column) == 0:
                placingSand = False
                print("Infinite Column")
                break 

            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)

    printSandMap(sandMap)


def findMax(sandMap,start,floor):
    infiniteFound = False
    current_step = 0
    while infiniteFound == False:
        #print()
        #printSandMap(sandMap)
        sandMap[(start[0],floor)] = "#"
        column = getColumn(sandMap,start[0],start[1])
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        current_loc = (closest[0],closest[1]-1)
        placingSand = True
        while placingSand:


            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)

            sandMap[(left[0],floor)] = "#"
            sandMap[(right[0],floor)] = "#"
            sandMap[(current_loc[0],floor)] = "#"

            if (left in sandMap) and (right in sandMap):
                sandMap[current_loc] = "o"
                placingSand = False
                if current_loc == start:
                    print("We did it boys")
                    infiniteFound = True
                    print(current_step+1)
                    break
            elif left not in sandMap:
                
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                
                column = getColumn(sandMap,right[0],right[1])

            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)
        current_step += 1
        

sandMap = {(500,0): "+"}
for rock in rockMap:
    sandMap[tuple(rock)] = "#"

print("Initial:")
print()
#simulateSand(sandMap,25,(500,0))
findMax(sandMap,(500,0),floor)
# Out:
# Floor:  172
# Initial:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 153
#     151 print()
#     152 #simulateSand(sandMap,25,(500,0))
# --> 153 findMax(sandMap,(500,0),floor)
#
# Cell In[3], line 128, in findMax(sandMap, start, floor)
#     125     column = getColumn(sandMap,left[0],left[1])
#     126 elif right not in sandMap:
# --> 128     column = getColumn(sandMap,right[0],right[1])
#     131 # if len(column) == 0:
#     132 #     placingSand = False
#     133 #     infiniteFound = True
#     134 #     print("Infinite Column")
#     135 #     print(current_step)
#     136 #     break
#     138 keys = list(column.keys())
#
# Cell In[3], line 56, in getColumn(sandMap, x_index, y_index)
#      55 def getColumn(sandMap,x_index,y_index):
# ...

# %%
from operator import sub
import heapq 

# Creates Rock coordinates
rockMap = []
for path in paths:
    #print("")
    for i in range(len(path)-1):
        coor_1 = path[i]
        coor_2 = path[i+1]  
        diffs = list(map(sub, coor_1, coor_2))
        #print(coor_1,coor_2,diffs)
        # X Case
        if coor_1[0] != coor_2[0]:
            min_x,max_x = min([coor_1[0],coor_2[0]]),max([coor_1[0],coor_2[0]]) 
            # print(min_y,max_y)
            x_ranges = range(min_x,max_x+1)
            for x in x_ranges:
                rockMap.append([x,coor_1[1]])

        # Y Case
        if coor_1[1] != coor_2[1]:
            min_y,max_y = min([coor_1[1],coor_2[1]]),max([coor_1[1],coor_2[1]]) 
            # print(min_y,max_y)
            y_ranges = range(min_y,max_y+1)
            for y in y_ranges:
                rockMap.append([coor_1[0],y])

floor = max(rockMap, key=lambda tup: tup[1])[1]+2
print("Floor: ", floor)

def printSandMap(sandMap):
    floor = 11
    keys = sandMap.keys()
    min_x = min(keys, key=lambda tup: tup[0])[0]
    max_x = max(keys, key=lambda tup: tup[0])[0]
    min_y = min(keys, key=lambda tup: tup[1])[1]
    max_y = max(keys, key=lambda tup: tup[1])[1]

    sand_spout = [500,0]
    buff = 4

    for y in range(min_y-buff,max_y+buff):
        row_string = ""
        for x in range(min_x-buff,max_x+buff):
            if (x,y) in sandMap:
                row_string += sandMap[(x,y)]
            else:
                row_string += "."
        print(row_string)

def getColumn(sandHeap,y_index,x_index):
    return list(filter(lambda elem: elem[1] == x_index and elem[0] >= y_index, sandHeap))
    #return dict(filter(lambda elem: elem[0][0] == x_index and elem[0][1] >= y_index and elem[1] != "+", sandMap.items()))


    
def findMaxHeaped(sandHeap,start,floor):
    print(sandHeap)
    infiniteFound = False
    current_step = 0
    while infiniteFound == False:
        if (start[0],floor) not in sandHeap:
            heapq.heappush(sandHeap, (start[0],floor))
        column = getColumn(sandHeap,start[0],start[1])
        print("Column: ",column)
        closest = heapq.heappop(column)
        current_loc = (closest[0],closest[1]-1)

        placing_sand = True
        while placing_sand:
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)

            if (left[0],floor) not in sandHeap:
                heapq.heappush(sandHeap, (left[0],floor))
            if (right[0],floor) not in sandHeap:
                heapq.heappush(sandHeap, (right[0],floor))
            if (current_loc[0],floor) not in sandHeap:
                heapq.heappush(sandHeap, (current_loc[0],floor))


            if (left in sandHeap) and (right in sandHeap):
                #sandHeap[current_loc] = "o"
                sandHeap.heappush(current_loc)
                placingSand = False
                if current_loc == start:
                    print("We did it boys")
                    infiniteFound = True
                    print(current_step+1)
                    break

            elif left not in sandHeap:
                column = getColumn(sandMap,left[0],left[1])

            elif right not in sandHeap:
                column = getColumn(sandMap,right[0],right[1])

            closest = heapq.heappop(column)
            current_loc = (closest[0],closest[1]-1)

        current_step += 1

        infiniteFound = True

    #     
    #     placingSand = True
    #     while placingSand:





        

sandMap = {(500,0): "+"}
sandHeap = []
for rock in rockMap:
    sandMap[tuple(rock)] = "#"
    heapq.heappush(sandHeap, (rock[1], rock[0]))

print("Initial:")
print()
print(sandHeap)
findMaxHeaped(sandHeap,(0,500),floor)
#findMax(sandMap,(500,0),floor)
# Out:
# Floor:  11
# Initial:
#
# [(4, 498), (4, 502), (4, 502), (4, 503), (5, 502), (6, 498), (6, 498), (6, 496), (5, 498), (6, 497), (6, 502), (7, 502), (8, 502), (9, 502), (9, 494), (9, 495), (9, 496), (9, 497), (9, 498), (9, 499), (9, 500), (9, 501), (9, 502)]
# [(4, 498), (4, 502), (4, 502), (4, 503), (5, 502), (6, 498), (6, 498), (6, 496), (5, 498), (6, 497), (6, 502), (7, 502), (8, 502), (9, 502), (9, 494), (9, 495), (9, 496), (9, 497), (9, 498), (9, 499), (9, 500), (9, 501), (9, 502)]
# Column:  [(9, 500)]
# (9, 500)

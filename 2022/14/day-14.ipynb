158]], [[518, 31], [518, 35], [517, 35], [517, 38], [529, 38], [529, 35], [522, 35], [522, 31]], [[490, 100], [495, 100]], [[481, 122], [481, 125], [476, 125], [476, 129], [491, 129], [491, 125], [485, 125], [485, 122]], [[500, 141], [505, 141]], [[499, 84], [499, 80], [499, 84], [501, 84], [501, 77], [501, 84], [503, 84], [503, 75], [503, 84], [505, 84], [505, 83], [505, 84]], [[475, 119], [475, 113], [475, 119], [477, 119], [477, 113], [477, 119], [479, 119], [479, 114], [479, 119], [481, 119], [481, 115], [481, 119], [483, 119], [483, 113], [483, 119]], [[518, 31], [518, 35], [517, 35], [517, 38], [529, 38], [529, 35], [522, 35], [522, 31]], [[490, 23], [490, 13], [490, 23], [492, 23], [492, 17], [492, 23], [494, 23], [494, 18], [494, 23], [496, 23], [496, 22], [496, 23], [498, 23], [498, 21], [498, 23], [500, 23], [500, 18], [500, 23], [502, 23], [502, 15], [502, 23], [504, 23], [504, 22], [504, 23], [506, 23], [506, 18], [506, 23], [508, 23], [508, 19], [508, 23]], [[495, 57], [499, 57]], [[489, 133], [489, 134], [494, 134]], [[488, 106], [493, 106]], [[519, 57], [523, 57]], [[481, 122], [481, 125], [476, 125], [476, 129], [491, 129], [491, 125], [485, 125], [485,  ...

# %%
from operator import sub

# Creates Rock coordinates
rockMap = []
for path in paths:
    #print("")
    for i in range(len(path)-1):
        coor_1 = path[i]
        coor_2 = path[i+1]  
        diffs = list(map(sub, coor_1, coor_2))
        #print(coor_1,coor_2,diffs)
        # X Case
        if coor_1[0] != coor_2[0]:
            min_x,max_x = min([coor_1[0],coor_2[0]]),max([coor_1[0],coor_2[0]]) 
            # print(min_y,max_y)
            x_ranges = range(min_x,max_x+1)
            for x in x_ranges:
                rockMap.append([x,coor_1[1]])

        # Y Case
        if coor_1[1] != coor_2[1]:
            min_y,max_y = min([coor_1[1],coor_2[1]]),max([coor_1[1],coor_2[1]]) 
            # print(min_y,max_y)
            y_ranges = range(min_y,max_y+1)
            for y in y_ranges:
                rockMap.append([coor_1[0],y])

def printSandMap(sandMap):
    keys = sandMap.keys()
    min_x = min(keys, key=lambda tup: tup[0])[0]
    max_x = max(keys, key=lambda tup: tup[0])[0]
    min_y = min(keys, key=lambda tup: tup[1])[1]
    max_y = max(keys, key=lambda tup: tup[1])[1]

    sand_spout = [500,0]
    # print("Printing Map: ")
    # print(min_x,max_x,min_y,max_y)

    # Buffers for better visuals larger maps
    buff = 4

    for y in range(min_y-buff,max_y+buff):
        row_string = ""
        for x in range(min_x-buff,max_x+buff):
            if (x,y) in sandMap:
                row_string += sandMap[(x,y)]
            else:
                row_string += "."
        print(row_string)

def getColumn(sandMap,x_index,y_index):
    return dict(filter(lambda elem: elem[0][0] == x_index and elem[0][1] >= y_index and elem[1] != "+", sandMap.items()))

def simulateSand(sandMap,steps,start):

    for i in range(steps):
        column = getColumn(sandMap,start[0],start[1])
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        current_loc = (closest[0],closest[1]-1)
        placingSand = True
        while placingSand:
            
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)
            if left in sandMap and right in sandMap:
                sandMap[current_loc] = "o"
                placingSand = False
            elif left not in sandMap:
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                column = getColumn(sandMap,right[0],right[1])
            
            if len(column) == 0:
                placingSand = False
                print("Infinite Column")
                break 

            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)

    printSandMap(sandMap)


def findMax(sandMap,start):
    infiniteFound = False
    current_step = 0
    while infiniteFound == False:
        column = getColumn(sandMap,start[0],start[1])
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        current_loc = (closest[0],closest[1]-1)
        placingSand = True
        while placingSand:
            
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)
            if left in sandMap and right in sandMap:
                sandMap[current_loc] = "o"
                placingSand = False
            elif left not in sandMap:
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                column = getColumn(sandMap,right[0],right[1])
            
            if len(column) == 0:
                placingSand = False
                infiniteFound = True
                print("Infinite Column")
                print(current_step)
                break 

            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)
        current_step += 1
    #printSandMap(sandMap)
        

sandMap = {(500,0): "+"}
for rock in rockMap:
    sandMap[tuple(rock)] = "#"

print("Initial:")
print()
#simulateSand(sandMap,25,(500,0))
findMax(sandMap,(500,0))
# Out:
# Initial:
#
# Infinite Column
# 24

# %%
# Creates Rock coordinates
rockMap = []
for path in paths:
    #print("")
    for i in range(len(path)-1):
        coor_1 = path[i]
        coor_2 = path[i+1]  
        diffs = list(map(sub, coor_1, coor_2))
        #print(coor_1,coor_2,diffs)
        # X Case
        if coor_1[0] != coor_2[0]:
            min_x,max_x = min([coor_1[0],coor_2[0]]),max([coor_1[0],coor_2[0]]) 
            # print(min_y,max_y)
            x_ranges = range(min_x,max_x+1)
            for x in x_ranges:
                rockMap.append([x,coor_1[1]])

        # Y Case
        if coor_1[1] != coor_2[1]:
            min_y,max_y = min([coor_1[1],coor_2[1]]),max([coor_1[1],coor_2[1]]) 
            # print(min_y,max_y)
            y_ranges = range(min_y,max_y+1)
            for y in y_ranges:
                rockMap.append([coor_1[0],y])

# %%
def printSandMap(sandMap):
    keys = sandMap.keys()
    min_x = min(keys, key=lambda tup: tup[0])[0]
    max_x = max(keys, key=lambda tup: tup[0])[0]
    min_y = min(keys, key=lambda tup: tup[1])[1]
    max_y = max(keys, key=lambda tup: tup[1])[1]

    sand_spout = [500,0]
    # print("Printing Map: ")
    # print(min_x,max_x,min_y,max_y)

    # Buffers for better visuals larger maps
    buff = 4

    for y in range(min_y-buff,max_y+buff):
        row_string = ""
        for x in range(min_x-buff,max_x+buff):
            if (x,y) in sandMap:
                row_string += sandMap[(x,y)]
            else:
                row_string += "."
        print(row_string)

# %%
from operator import sub



def simulateSand(sandMap,steps,start):

    for i in range(steps):
        column = getColumn(sandMap,start[0],start[1])
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        current_loc = (closest[0],closest[1]-1)
        placingSand = True
        while placingSand:
            
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)
            if left in sandMap and right in sandMap:
                sandMap[current_loc] = "o"
                placingSand = False
            elif left not in sandMap:
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                column = getColumn(sandMap,right[0],right[1])
            
            if len(column) == 0:
                placingSand = False
                print("Infinite Column")
                break 

            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)

    printSandMap(sandMap)


def findMax(sandMap,start):
    infiniteFound = False
    current_step = 0
    while infiniteFound == False:
        column = getColumn(sandMap,start[0],start[1])
        keys = list(column.keys())
        keys.sort(key=lambda coord: coord[1],reverse=False)
        closest = keys[0]
        current_loc = (closest[0],closest[1]-1)
        placingSand = True
        while placingSand:
            
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)
            if left in sandMap and right in sandMap:
                sandMap[current_loc] = "o"
                placingSand = False
            elif left not in sandMap:
                column = getColumn(sandMap,left[0],left[1])
            elif right not in sandMap:
                column = getColumn(sandMap,right[0],right[1])
            
            if len(column) == 0:
                placingSand = False
                infiniteFound = True
                print("Infinite Column")
                print(current_step)
                break 

            keys = list(column.keys())
            keys.sort(key=lambda coord: coord[1],reverse=False)
            closest = keys[0]
            current_loc = (closest[0],closest[1]-1)
        current_step += 1
    #printSandMap(sandMap)
        

sandMap = {(500,0): "+"}
for rock in rockMap:
    sandMap[tuple(rock)] = "#"

print("Initial:")
print()
#simulateSand(sandMap,25,(500,0))
findMax(sandMap,(500,0))

# %%
floor = max(rockMap, key=lambda tup: tup[1])[1]+2
print("floor:",floor)

#def getColumn(sandMap,x_index,y_index):
#    return dict(filter(lambda elem: elem[0][0] == x_index and elem[0][1] >= y_index and elem[1] != "+", sandMap.items()))

def printSandSet(sandSet):
    min_x = min(sandSet, key=lambda tup: tup[0])[0]
    max_x = max(sandSet, key=lambda tup: tup[0])[0]
    min_y = min(sandSet, key=lambda tup: tup[1])[1]
    max_y = max(sandSet, key=lambda tup: tup[1])[1]

    sand_spout = [500,0]
    # print("Printing Map: ")
    # print(min_x,max_x,min_y,max_y)

    # Buffers for better visuals larger maps
    buff = 4

    for y in range(min_y-buff,max_y+buff):
        row_string = ""
        for x in range(min_x-buff,max_x+buff):
            if (x,y) in sandSet:
                row_string += "#"
            else:
                row_string += "."
        print(row_string)


def getLowest(sandMap,point):
    not_found = True
    while not_found:
        point = (point[0], point[1]+1)
        if point in sandMap:
            return (point[0],point[1]-1)


def findMaxFloor(sandMap,start,floor):
    
    infiniteFound = False
    current_step = 0
    while infiniteFound == False:
        #column = getColumn(sandMap,start[0],start[1])
        # keys = list(column)
        # keys.sort(key=lambda coord: coord[1],reverse=False)
        # closest = keys[0]
        current_loc = getLowest(sandMap,start)
        placingSand = True
        while placingSand:
            left = (current_loc[0]-1,current_loc[1]+1)
            right = (current_loc[0]+1,current_loc[1]+1)
            sandMap.add((current_loc[0],floor))
            sandMap.add((left[0],floor))
            sandMap.add((right[0],floor))

            if left in sandMap and right in sandMap:
                sandMap.add(current_loc)
                placingSand = False
                if current_loc==start:
                    placingSand = False
                    infiniteFound = True
                    print("Infinite Column")
                    print(current_step+1)
                    break 

            elif left not in sandMap:
                current_loc = getLowest(sandMap,left)

            elif right not in sandMap:
                current_loc = getLowest(sandMap,right)

        current_step += 1

blocked_set = set([])
for rock in rockMap:
    blocked_set.add(tuple(rock))


findMaxFloor(blocked_set,(500,0),floor)
# Out:
# floor: 172
# Infinite Column
# 27601
